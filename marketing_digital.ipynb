# %% [markdown]
# <a href="https://colab.research.google.com/github/stefymojica/Proyecto_ML/blob/master/marketing_digital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MARKETING DIGITAL**
#
#
# ---

# %% [markdown]
# Objetivo: Crear un modelo predictivo que permita predecir el CTR(click throught rate)

# %%
import pandas as pd
import numpy as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import labelEncoder, StandardScaler
from

# %%
XY = pd.read_csv("https://proyectosmachinelearning.s3.us-east-2.amazonaws.com/Base_proyecto.csv")

# %%
XY.head()
# Out:
#    id ad_position  ad_size  ...  clicks impressions       ctr
# 0   1  FULLSCREEN  320x480  ...       6          29  0.206897
# 1   2  FULLSCREEN  320x480  ...      13          86  0.151163
# 2   3           0  320x480  ...       0          11  0.000000
# 3   4  FULLSCREEN  320x480  ...       0          38  0.000000
# 4   5           0  320x480  ...       0          19  0.000000
#
# [5 rows x 13 columns]
